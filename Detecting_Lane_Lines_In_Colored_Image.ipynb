# %% [markdown]
# # **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# # **Read Image and Display it**

# %%
image_color=cv2.imread('/content/drive/MyDrive/Helios/1.png')
image_color.shape
# Out:
# (189, 328, 3)

# %% [markdown]
# # **Sorting Out White Color**

# %%
image_copy=np.copy(image_color)
image_copy.shape
# Out:
# (189, 328, 3)

# %%
image_copy[(image_copy[:,:,0]<200)|(image_copy[:,:,1]<200)|(image_copy[:,:,2]<200)]=0

# %%
plt.imshow(image_copy,cmap='gray')
